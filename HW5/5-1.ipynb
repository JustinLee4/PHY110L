# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import scipy as sc
import copy
import matplotlib.gridspec as gridspec
from matplotlib import cm

# %%
maxN = 5
Vinitial = 1

# %%
def V(x, y, maxN, L):
    sum = 0
    for n in range (1, maxN+1):
        if(n % 2 == 1):
            an = 4 * Vinitial / (n * np.pi)
            sum = sum + an * np.sin(n*np.pi*x / L) * np.exp(-n * np.pi * y / L)
    return sum

# %%
coords = np.mgrid[0:101, 0:51]
ygrid = coords[0,:,:]
xgrid = coords[1,:,:]

# %%
Potential = V(xgrid, yagrid, maxN, 50)

# %%
# %matplotlib widget

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
ax.plot_surface(xgrid,ygrid,Potential, cmap= cm.coolwarm)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Potential50 = V(xgrid, ygrid, 50, 50)
# %matplotlib widget

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
ax.plot_surface(xgrid,ygrid,Potential50, cmap= cm.coolwarm)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Potential500 = V(xgrid, ygrid, 500, 50)
# %matplotlib widget

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
ax.plot_surface(xgrid,ygrid,Potential500, cmap= cm.coolwarm)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# V = V0 at y = 0 is the boundary condition that gets better matched as n increases.
# This is because y = 0 is the highest potential part of the box, and so the sum must iterate
# the most times to approach convergence where the potential is highest.
